# %%
import torch.nn as nn
import torch.nn.parallel
import random
import argparse
# from network.resnet import resnet18, resnet34
# from network.pointnet import PointNetCls
from torch.utils.data import DataLoader
import os
import numpy as np
from Models import FMNIST_classifier
from fmnist_prepare_subset_select_train_val_test import F_MNIST
import torch.optim as optim
from torch.optim import lr_scheduler
import torchvision.transforms as transforms
from termcolor import cprint
# from knn_utils import calc_knn_graph, calc_topo_weights_with_components_idx
from subset_select_ipot_non_uniform_git import subset_select_ipot as ss_ipot
from noise import noisify_with_P, noisify_cifar10_asymmetric, noisify_cifar100_asymmetric, noisify_pairflip, noisify_modelnet40_asymmetric
import copy
from scipy.stats import mode
from matplotlib import pyplot as plt
import torch.nn.functional as F

if torch.cuda.is_available():
    device = torch.device("cuda:0")
else:
    device = "cpu"

# %% [markdown]
# # Clean Data

# %%
# def _init_fn(worker_id):
#     np.random.seed(77 + worker_id)

# models_path = "G:\\My Drive\\Research Codes\\Subset Selection Paper\\Neural Network Classifier\\models\\UCI-subset-select\\Fashion-MNIST\\"

# train_val_ratio = 0.8
# trust_prop = 0.5
# noise_level = 0.8
# batch_size_train = 512
# num_classes = 10
# random_seed = 42
# max_epochs = 200

# transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))])


# trainset = F_MNIST(root='./data', split='train', train_ratio=train_val_ratio,trust_prop=trust_prop,  download=True, transform=transform)
# trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True, num_workers=0, worker_init_fn=_init_fn)

# noise_y_train_labels0, noise_y_train_indices = trainset.get_noisy_labels_with_indices()
# noise_y_train, p, _ = noisify_with_P(noise_y_train_labels0, nb_classes=num_classes, noise=noise_level, random_state=random_seed)
# trainset.update_corrupted_label(noise_y_train, noise_y_train_indices)

# valset = F_MNIST(root='./data', split='val', train_ratio=train_val_ratio, trust_prop=trust_prop, download=True, transform=transform)
# valloader = torch.utils.data.DataLoader(valset, batch_size=512, shuffle=False, num_workers=0)

# testset = F_MNIST(root='./data', split='test', download=True, transform=transform)
# testloader = torch.utils.data.DataLoader(
#     testset, batch_size=512, shuffle=False, num_workers=0)



# unique_labels = [int(i) for i in list(np.linspace(0, 10, 10, endpoint=False))]
# torch.manual_seed(0)

# net = FMNIST_classifier().to(device)
# criterion = nn.CrossEntropyLoss(reduction='mean')
# optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(0.9, 0.999), eps=1e-08, weight_decay=1e-4)


# train_acc = []
# val_acc = []
# best_accuracy = 0

# for epoch in range(max_epochs):  # loop over the dataset multiple times

#     running_loss = []
#     for i, data in enumerate(trainloader, 0):
#         # get the inputs; data is a list of [inputs, labels]
#         # _, images, labels, _, _ = data
#         images, labels, _, _, _ = data
#         # zero the parameter gradients
#         optimizer.zero_grad()

#         # forward + backward + optimize
#         outputs, _ = net(images.double().to(device))
#         loss = criterion(outputs, labels.long().to(device))
#         loss.backward()
#         optimizer.step()

#         running_loss.append(loss.item())
#         # avg_loss.append(torch.tensor(running_loss).mean())
#     print("epoch={0:d},  avg_loss = {1:0.4f}".format(
#         epoch, torch.tensor(running_loss).mean()))

#     if True:
#         classes = tuple([str(i) for i in unique_labels])
#         correct_pred = {classname: 0 for classname in classes}
#         total_pred = {classname: 0 for classname in classes}
#         total = 0
#         correct = 0

#         net.eval()
#         with torch.no_grad():
#             for data in valloader:
#                 images, labels, _, _, _ = data
#                 outputs, _ = net(images.double().to(device))
#                 _, predictions = torch.max(outputs, dim=1)
#                 total += labels.size(0)
#                 correct += (predictions.cpu() == labels).sum().item()
#             print(f'val set accuraccy: {100 * correct / total} %')
#             val_acc.append(100 * correct / total)

#         if val_acc[-1] > best_accuracy:
#             best_accuracy = val_acc[-1]
#             net_path = models_path + "FMNIST_clean"+".pth"
#             torch.save({
#                 'epoch': epoch,
#                 'model_state_dict': net.state_dict(),
#                 'optimizer_state_dict': optimizer.state_dict(),
#                 'val-accuracy': val_acc,
#                 'train-accuracy': train_acc}, net_path)

#         classes = tuple([str(i) for i in unique_labels])
#         correct_pred = {classname: 0 for classname in classes}
#         total_pred = {classname: 0 for classname in classes}
#         total = 0
#         correct = 0
#         net.eval()
#         with torch.no_grad():
#             for data in trainloader:
#                 images, labels, _, _, _ = data
#                 outputs, _ = net(images.double().to(device))
#                 _, predictions = torch.max(outputs, dim=1)
#                 total += labels.size(0)
#                 correct += (predictions.cpu() == labels).sum().item()
#         print(f'train set accuracy: {100 * correct / total} %')
#         train_acc.append(100 * correct / total)


# print('Finished Training')
# # saving training accuracy list along with model with best accuracy
# net_path = models_path + "FMNIST_clean"+".pth"
# best_net_dict = torch.load(net_path)
# best_net_dict['val-accuracy'] = val_acc
# best_net_dict['train-accuracy'] = train_acc
# torch.save(best_net_dict, net_path)

# %%
# from matplotlib import pyplot as plt
# net_path = models_path + "FMNIST_clean"+".pth"
# best_net_dict = torch.load(net_path)

# iters = list(range(0, 100))
# fig, axs = plt.subplots()
# axs.plot(iters, best_net_dict['val-accuracy'],
#          "-.", color="r", label="validation")
# axs.plot(iters, best_net_dict['train-accuracy'],
#          "-.", color="b", label="train")
# axs.set_xlabel("iters.")
# axs.set_ylabel("accuracy")
# fig.legend(ncol=3, loc=(0.4, 0.13))

# %% [markdown]
# # Noisy Data

# %%
# def _init_fn(worker_id):
#     np.random.seed(77 + worker_id)


# models_path = "G:\\My Drive\\Research Codes\\Subset Selection Paper\\Neural Network Classifier\\models\\UCI-subset-select\\Fashion-MNIST\\"

# train_val_ratio = 0.8
# trust_prop = 0.5

# batch_size_train = 512

# num_classes = 10

# noise_level = 0.8
# random_seed = 42

# transform_train = transforms.Compose(
#     [transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
# trainset = F_MNIST(root='./data', split='train', train_ratio=train_val_ratio,
#                  trust_prop=trust_prop,  download=True, transform=transform_train)
# trainloader = torch.utils.data.DataLoader(
#     trainset, batch_size=512, shuffle=True, num_workers=0, worker_init_fn=_init_fn)


# noise_y_train_labels0, noise_y_train_indices = trainset.get_noisy_labels_with_indices()
# noise_y_train, p, _ = noisify_with_P(
#     noise_y_train_labels0, nb_classes=num_classes, noise=noise_level, random_state=random_seed)
# trainset.update_corrupted_label(noise_y_train, noise_y_train_indices)

# valset = F_MNIST(root='./data', split='val', train_ratio=train_val_ratio,
#                trust_prop=trust_prop, download=True, transform=transform_train)
# valloader = torch.utils.data.DataLoader(
#     valset, batch_size=512, shuffle=False, num_workers=0)

# testset = F_MNIST(root='./data', split='test',
#                 download=True, transform=transform_train)
# testloader = torch.utils.data.DataLoader(
#     testset, batch_size=512, shuffle=False, num_workers=0)

# max_epochs = 100
# unique_labels = [int(i) for i in list(np.linspace(0, 10, 10, endpoint=False))]
# torch.manual_seed(0)

# net = FMNIST_classifier().to(device)
# criterion = nn.CrossEntropyLoss(reduction='mean')
# optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(
#     0.9, 0.999), eps=1e-08, weight_decay=1e-4)

# train_acc = []
# val_acc = []
# best_accuracy = 0

# for epoch in range(max_epochs):  # loop over the dataset multiple times

#     running_loss = []
#     for i, data in enumerate(trainloader, 0):
#         # get the inputs; data is a list of [inputs, labels]
#         # _, images, labels, _, _ = data
#         images, labels, _, _, _ = data
#         # zero the parameter gradients
#         optimizer.zero_grad()

#         # forward + backward + optimize
#         outputs, _ = net(images.double().to(device))
#         loss = criterion(outputs, labels.long().to(device))
#         loss.backward()
#         optimizer.step()

#         running_loss.append(loss.item())
#         # avg_loss.append(torch.tensor(running_loss).mean())
#     print("epoch={0:d},  avg_loss = {1:0.4f}".format(
#         epoch, torch.tensor(running_loss).mean()))

#     if True:
#         classes = tuple([str(i) for i in unique_labels])
#         correct_pred = {classname: 0 for classname in classes}
#         total_pred = {classname: 0 for classname in classes}
#         total = 0
#         correct = 0

#         net.eval()
#         with torch.no_grad():
#             for data in valloader:
#                 images, labels, _, _, _ = data
#                 outputs, _ = net(images.double().to(device))
#                 _, predictions = torch.max(outputs, dim=1)
#                 total += labels.size(0)
#                 correct += (predictions.cpu() == labels).sum().item()
#             print(f'val set accuraccy: {100 * correct / total} %')
#             val_acc.append(100 * correct / total)

#         if val_acc[-1] > best_accuracy:
#             best_accuracy = val_acc[-1]
#             net_path = models_path + "FMNIST_noisy"+".pth"
#             torch.save({
#                 'epoch': epoch,
#                 'model_state_dict': net.state_dict(),
#                 'optimizer_state_dict': optimizer.state_dict(),
#                 'val-accuracy': val_acc,
#                 'train-accuracy': train_acc}, net_path)

#         classes = tuple([str(i) for i in unique_labels])
#         correct_pred = {classname: 0 for classname in classes}
#         total_pred = {classname: 0 for classname in classes}
#         total = 0
#         correct = 0
#         net.eval()
#         with torch.no_grad():
#             for data in trainloader:
#                 images, labels, _, _, _ = data
#                 outputs, _ = net(images.double().to(device))
#                 _, predictions = torch.max(outputs, dim=1)
#                 total += labels.size(0)
#                 correct += (predictions.cpu() == labels).sum().item()
#         print(f'train set accuracy: {100 * correct / total} %')
#         train_acc.append(100 * correct / total)


# print('Finished Training')
# # saving training accuracy list along with model with best accuracy
# net_path = models_path + "FMNIST_noisy"+".pth"
# best_net_dict = torch.load(net_path)
# best_net_dict['val-accuracy'] = val_acc
# best_net_dict['train-accuracy'] = train_acc
# torch.save(best_net_dict, net_path)

# %%
# from matplotlib import pyplot as plt
# net_path = models_path + "FMNIST_noisy"+".pth"
# best_net_dict = torch.load(net_path)


# iters = list(range(0, 100))
# fig, axs = plt.subplots()
# axs.plot(iters, best_net_dict['val-accuracy'], "-.", color="r", label="validation")
# axs.plot(iters, best_net_dict['train-accuracy'], "-.", color="b", label="train")
# axs.set_xlabel("iters.")
# axs.set_ylabel("accuracy")
# fig.legend(ncol=3, loc=(0.4, 0.13))

# %% [markdown]
# # Subset Selection

# %%
def _init_fn(worker_id):
    np.random.seed(77 + worker_id)

models_path = "G:\\My Drive\\Research Codes\\Subset Selection Paper\\Neural Network Classifier\\models\\UCI-subset-select\\Fashion-MNIST\\"

train_val_ratio = 0.8
trust_prop = 0.5

batch_size_train = 512

num_classes = 10

noise_level = 0.8
random_seed = 42

# cs = [1, 2, 3, 4, 5, 6, 7, 8, 20]
cs = [2, 3, 4, 5, 6, 7, 8, 20]
max_epochs = 200
gamma_ss = 0.1

# models_path + "ss_1 " +  "cifar10 " + "c={cs:2d}".format(cs=c)+".pth"

for c in cs:
    print("c = ", c)

    torch.manual_seed(0)

    transform_train = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.1307,), (0.3081,))])
    trainset = F_MNIST(root='./data', split='train', train_ratio=train_val_ratio,trust_prop=trust_prop,  download=True, transform=transform_train)
    trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, shuffle=True, num_workers=0, worker_init_fn=_init_fn)

    noise_y_train_labels0, noise_y_train_indices = trainset.get_noisy_labels_with_indices()
    noise_y_train, p, _ = noisify_with_P(noise_y_train_labels0, nb_classes=num_classes, noise=noise_level, random_state=random_seed)
    trainset.update_corrupted_label(noise_y_train, noise_y_train_indices)

    valset = F_MNIST(root='./data', split='val', train_ratio=train_val_ratio,trust_prop=trust_prop, download=True, transform=transform_train)
    valloader = torch.utils.data.DataLoader(
        valset, batch_size=512, shuffle=False, num_workers=0)

    testset = F_MNIST(root='./data', split='test',
                      download=True, transform=transform_train)
    testloader = torch.utils.data.DataLoader(
        testset, batch_size=512, shuffle=False, num_workers=0)

    unique_labels = [int(i)
                     for i in list(np.linspace(0, 10, 10, endpoint=False))]
    torch.manual_seed(0)

    net = FMNIST_classifier().to(device)
    criterion = nn.CrossEntropyLoss(reduction='mean')
    optimizer = optim.Adam(net.parameters(), lr=0.001, betas=(
        0.9, 0.999), eps=1e-08, weight_decay=1e-4)

    train_acc = []
    val_acc = []
    best_accuracy = 0

    for epoch in range(max_epochs):  # loop over the dataset multiple times

        running_loss = []
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            # _, images, labels, _, _ = data
            images, labels, weights, cd_y, idx = data
            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs, encodings = net(images.to(device))

            x = encodings[cd_y == 1].detach().cpu()
            y = encodings[cd_y == 0].detach().cpu()
            x_labels = labels[cd_y == 1].detach().cpu()
            y_labels = labels[cd_y == 0].detach().cpu()
            x_idx = idx[cd_y == 1].detach().cpu()
            y_idx = idx[cd_y == 0].detach().cpu()

            x_labels_onehot = (F.one_hot(x_labels.long(), num_classes=num_classes)).to(
                device).double()

            mu = 1/x.shape[0]*np.ones(x.shape[0])
            nu = 1/y.shape[0]*np.ones(y.shape[0])
            costs, P, _, _ = ss_ipot(x, y, mu, nu, c,  gamma_ss, max_outer_iter=20, max_inner_iter=20, wd=2, disp_iter=False, return_map=True)

            P_torch = torch.from_numpy(P).to(device)
            y_labels_hat = (P_torch.T@x_labels_onehot.double()).to(device)

            input_labels_hat = torch.zeros_like(outputs, device=device, dtype=torch.double)
            input_labels_hat[cd_y == 1] = 1 / x.shape[0] * (x_labels_onehot.double())
            input_labels_hat[cd_y == 0] = y_labels_hat

            loss = - torch.sum(input_labels_hat*F.log_softmax(outputs, dim=1))
            loss.backward()
            optimizer.step()
            running_loss.append(loss.item())
            # avg_loss.append(torch.tensor(running_loss).mean())
        print("epoch={0:d},  avg_loss = {1:0.4f}".format(
            epoch, torch.tensor(running_loss).mean()))

        if True:
            classes = tuple([str(i) for i in unique_labels])
            correct_pred = {classname: 0 for classname in classes}
            total_pred = {classname: 0 for classname in classes}
            total = 0
            correct = 0

            net.eval()
            with torch.no_grad():
                for data in valloader:
                    images, labels, _, _, _ = data
                    outputs, _ = net(images.to(device))
                    _, predictions = torch.max(outputs, dim=1)
                    total += labels.size(0)
                    correct += (predictions.cpu() == labels).sum().item()
                print(f'val set accuraccy: {100 * correct / total} %')
                val_acc.append(100 * correct / total)

            if val_acc[-1] > best_accuracy:
                best_accuracy = val_acc[-1]
                net_path = models_path + "ss_1 " + "gamma=0.1" + "fmnist " + "c={cs:2d}".format(cs=c)+".pth"
                torch.save({
                    'epoch': epoch,
                    'model_state_dict': net.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'val-accuracy': val_acc,
                    'train-accuracy': train_acc}, net_path)

            classes = tuple([str(i) for i in unique_labels])
            correct_pred = {classname: 0 for classname in classes}
            total_pred = {classname: 0 for classname in classes}
            total = 0
            correct = 0
            net.eval()
            with torch.no_grad():
                for data in trainloader:
                    images, labels, _, _, _ = data
                    outputs, _ = net(images.to(device))
                    _, predictions = torch.max(outputs, dim=1)
                    total += labels.size(0)
                    correct += (predictions.cpu() == labels).sum().item()
            print(f'train set accuracy: {100 * correct / total} %')
            train_acc.append(100 * correct / total)

    print('Finished Training')
    # saving training accuracy list along with model with best accuracy
    net_path = models_path + "ss_1 " + "gamma=0.1"+"fmnist " + "c={cs:2d}".format(cs=c)+".pth"
    best_net_dict = torch.load(net_path)
    best_net_dict['val-accuracy'] = val_acc
    best_net_dict['train-accuracy'] = train_acc
    torch.save(best_net_dict, net_path)
# Out:
# c =  2
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz to ./data\F_MNIST\raw\train-images-idx3-ubyte.gz
# 0.00B [00:00, ?B/s]
# 26.4MB [00:10, 2.41MB/s]
# Extracting ./data\F_MNIST\raw\train-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz to ./data\F_MNIST\raw\train-labels-idx1-ubyte.gz
# 32.8kB [00:00, 83.2kB/s]
# Extracting ./data\F_MNIST\raw\train-labels-idx1-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz to ./data\F_MNIST\raw\t10k-images-idx3-ubyte.gz
# 4.42MB [00:02, 2.17MB/s]
# Extracting ./data\F_MNIST\raw\t10k-images-idx3-ubyte.gz
# Downloading http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz to ./data\F_MNIST\raw\t10k-labels-idx1-ubyte.gz
# 8.19kB [00:00, 29.0kB/s]
# g:\My Drive\Research Codes\Subset Selection Paper\Neural Network Classifier\USPS\FashionMNIST\Lambda training\fmnist_prepare_subset_select_train_val_test.py:262: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  C:\cb\pytorch_1000000000000\work\torch\csrc\utils\tensor_numpy.cpp:178.)
#   return torch.from_numpy(parsed).view(length, num_rows, num_cols)
# Extracting ./data\F_MNIST\raw\t10k-labels-idx1-ubyte.gz
# Processing...
# Done!
# Actual noise 0.80
# epoch=0,  avg_loss = 1.5966
# val set accuraccy: 80.18333333333334 %
# train set accuracy: 49.50625 %
# epoch=1,  avg_loss = 1.0606
# val set accuraccy: 84.14166666666667 %
# train set accuracy: 52.03541666666667 %
# epoch=2,  avg_loss = 0.8812
# val set accuraccy: 85.70833333333333 %
# train set accuracy: 52.88333333333333 %
# epoch=3,  avg_loss = 0.8060
# val set accuraccy: 88.15833333333333 %
# train set accuracy: 54.36666666666667 %
# epoch=4,  avg_loss = 0.7467
# val set accuraccy: 88.88333333333334 %
# train set accuracy: 54.78958333333333 %
# epoch=5,  avg_loss = 0.6927
# val set accuraccy: 88.36666666666666 %
# train set accuracy: 54.70625 %
# epoch=6,  avg_loss = 0.6896
# val set accuraccy: 88.90833333333333 %
# train set accuracy: 55.360416666666666 %
# epoch=7,  avg_loss = 0.6447
# val set accuraccy: 89.95833333333333 %
# train set accuracy: 55.925 %
# epoch=8,  avg_loss = 0.6051
# val set accuraccy: 89.95 %
# train set accuracy: 56.141666666666666 %
# epoch=9,  avg_loss = 0.5886
# val set accuraccy: 89.65833333333333 %
# train set accuracy: 56.15208333333333 %
# epoch=10,  avg_loss = 0.5693
# val set accuraccy: 89.94166666666666 %
# train set accuracy: 56.46875 %
# epoch=11,  avg_loss = 0.5611
# val set accuraccy: 89.80833333333334 %
# train set accuracy: 56.795833333333334 %
# epoch=12,  avg_loss = 0.5424
# val set accuraccy: 90.23333333333333 %
# train set accuracy: 57.2625 %
# epoch=13,  avg_loss = 0.5471
# val set accuraccy: 90.225 %
# train set accuracy: 57.13333333333333 %
# epoch=14,  avg_loss = 0.5404
# val set accuraccy: 89.91666666666667 %
# train set accuracy: 57.525 %
# epoch=15,  avg_loss = 0.5271
# val set accuraccy: 90.225 %
# train set accuracy: 57.675 %
# epoch=16,  avg_loss = 0.5372
# val set accuraccy: 89.91666666666667 %
# train set accuracy: 57.84166666666667 %
# epoch=17,  avg_loss = 0.5458
# val set accuraccy: 89.68333333333334 %
# train set accuracy: 57.80416666666667 %
# epoch=18,  avg_loss = 0.5500
# val set accuraccy: 90.025 %
# train set accuracy: 58.33125 %
# epoch=19,  avg_loss = 0.5642
# val set accuraccy: 90.01666666666667 %
# train set accuracy: 58.422916666666666 %
# epoch=20,  avg_loss = 0.5425
# val set accuraccy: 89.625 %
# train set accuracy: 58.34375 %
# epoch=21,  avg_loss = 0.5730
# val set accuraccy: 89.90833333333333 %
# train set accuracy: 58.485416666666666 %
# epoch=22,  avg_loss = 0.5555
# val set accuraccy: 89.875 %
# train set accuracy: 58.5625 %
# epoch=23,  avg_loss = 0.5493
# val set accuraccy: 89.79166666666667 %
# train set accuracy: 58.766666666666666 %
# epoch=24,  avg_loss = 0.6283
# val set accuraccy: 89.76666666666667 %
# train set accuracy: 58.70625 %
# epoch=25,  avg_loss = 0.5679
# val set accuraccy: 89.50833333333334 %
# train set accuracy: 58.7125 %
# epoch=26,  avg_loss = 0.6045
# val set accuraccy: 89.20833333333333 %
# train set accuracy: 58.75208333333333 %
# epoch=27,  avg_loss = 0.5867
# val set accuraccy: 88.975 %
# train set accuracy: 58.50625 %
# epoch=28,  avg_loss = 0.6137
# val set accuraccy: 84.325 %
# train set accuracy: 58.729166666666664 %
# epoch=56,  avg_loss = 1.0579
# val set accuraccy: 84.88333333333334 %
# train set accuracy: 58.77916666666667 %
# epoch=57,  avg_loss = 1.0326
# val set accuraccy: 84.3 %
# train set accuracy: 58.79375 %
# epoch=58,  avg_loss = 1.0282
# val set accuraccy: 84.075 %
# train set accuracy: 58.54375 %
# epoch=59,  avg_loss = 1.0011
# val set accuraccy: 83.55833333333334 %
# train set accuracy: 58.666666666666664 %
# epoch=60,  avg_loss = 1.0661
# val set accuraccy: 83.96666666666667 %
# train set accuracy: 58.69375 %
# epoch=61,  avg_loss = 1.0404
# val set accuraccy: 82.71666666666667 %
# train set accuracy: 58.422916666666666 %
# epoch=62,  avg_loss = 1.0075
# val set accuraccy: 83.15833333333333 %
# train set accuracy: 58.520833333333336 %
# epoch=63,  avg_loss = 1.0259
# val set accuraccy: 83.70833333333333 %
# train set accuracy: 58.577083333333334 %
# epoch=64,  avg_loss = 1.0480
# val set accuraccy: 82.16666666666667 %
# train set accuracy: 58.4 %
# epoch=65,  avg_loss = 1.0563
# val set accuraccy: 82.58333333333333 %
# train set accuracy: 58.43333333333333 %
# epoch=66,  avg_loss = 1.0971
# val set accuraccy: 82.28333333333333 %
# train set accuracy: 58.333333333333336 %
# epoch=67,  avg_loss = 1.0683
# val set accuraccy: 82.925 %
# train set accuracy: 58.54375 %
# epoch=68,  avg_loss = 1.0848
# val set accuraccy: 81.975 %
# train set accuracy: 58.322916666666664 %
# epoch=69,  avg_loss = 1.0900
# val set accuraccy: 82.70833333333333 %
# train set accuracy: 58.4875 %
# epoch=70,  avg_loss = 1.0788
# val set accuraccy: 82.35 %
# train set accuracy: 58.489583333333336 %
# epoch=71,  avg_loss = 1.1191
# val set accuraccy: 82.11666666666666 %
# train set accuracy: 58.385416666666664 %
# epoch=72,  avg_loss = 1.1335
# val set accuraccy: 81.65 %
# train set accuracy: 58.31458333333333 %
# epoch=73,  avg_loss = 1.1112
# val set accuraccy: 82.05833333333334 %
# train set accuracy: 58.49583333333333 %
# epoch=74,  avg_loss = 1.1176
# val set accuraccy: 81.575 %
# train set accuracy: 58.22708333333333 %
# epoch=75,  avg_loss = 1.1280
# val set accuraccy: 82.63333333333334 %
# train set accuracy: 58.3875 %
# epoch=76,  avg_loss = 1.1113
# val set accuraccy: 80.7 %
# train set accuracy: 58.16458333333333 %
# epoch=77,  avg_loss = 1.1093
# val set accuraccy: 81.23333333333333 %
# train set accuracy: 58.30625 %
# epoch=78,  avg_loss = 1.1250
# val set accuraccy: 80.575 %
# train set accuracy: 58.15416666666667 %
# epoch=79,  avg_loss = 1.1916
# val set accuraccy: 81.15 %
# train set accuracy: 58.27291666666667 %
# epoch=80,  avg_loss = 1.1322
# val set accuraccy: 80.35833333333333 %
# train set accuracy: 58.18125 %
# epoch=81,  avg_loss = 1.1610
# val set accuraccy: 80.55833333333334 %
# train set accuracy: 58.177083333333336 %
# train set accuracy: 59.19166666666667 %
# epoch=42,  avg_loss = 0.6454
# val set accuraccy: 87.69166666666666 %
# train set accuracy: 59.172916666666666 %
# epoch=43,  avg_loss = 0.6517
# val set accuraccy: 86.95 %
# train set accuracy: 58.93333333333333 %
# epoch=44,  avg_loss = 0.7481
# val set accuraccy: 87.09166666666667 %
# train set accuracy: 59.114583333333336 %
# epoch=45,  avg_loss = 0.8292
# val set accuraccy: 87.35 %
# train set accuracy: 59.225 %
# epoch=46,  avg_loss = 0.8017
# val set accuraccy: 86.54166666666667 %
# train set accuracy: 59.01875 %
# epoch=47,  avg_loss = 0.8346
# val set accuraccy: 86.91666666666667 %
# train set accuracy: 59.1125 %
# epoch=48,  avg_loss = 0.8231
# val set accuraccy: 85.75 %
# train set accuracy: 58.927083333333336 %
# epoch=49,  avg_loss = 0.8976
# val set accuraccy: 86.29166666666667 %
# train set accuracy: 58.916666666666664 %
# epoch=50,  avg_loss = 0.8214
# val set accuraccy: 86.53333333333333 %
# train set accuracy: 59.09166666666667 %
# epoch=51,  avg_loss = 0.8278
# val set accuraccy: 86.45 %
# train set accuracy: 59.0875 %
# epoch=52,  avg_loss = 0.8430
# val set accuraccy: 86.14166666666667 %
# train set accuracy: 58.97083333333333 %
# epoch=53,  avg_loss = 0.9124
# val set accuraccy: 86.06666666666666 %
# train set accuracy: 58.822916666666664 %
# epoch=54,  avg_loss = 0.9036
# val set accuraccy: 85.75833333333334 %
# train set accuracy: 58.9125 %
# epoch=55,  avg_loss = 0.9486
# val set accuraccy: 85.225 %
# train set accuracy: 58.802083333333336 %
# epoch=56,  avg_loss = 0.9659
# val set accuraccy: 85.25 %
# train set accuracy: 58.958333333333336 %
# epoch=57,  avg_loss = 0.9747
# val set accuraccy: 85.23333333333333 %
# train set accuracy: 58.84166666666667 %
# epoch=58,  avg_loss = 0.9319
# val set accuraccy: 84.78333333333333 %
# train set accuracy: 58.8 %
# epoch=59,  avg_loss = 0.9691
# val set accuraccy: 84.24166666666666 %
# train set accuracy: 58.7 %
# epoch=60,  avg_loss = 0.9910
# val set accuraccy: 85.55833333333334 %
# train set accuracy: 58.87291666666667 %
# epoch=61,  avg_loss = 0.9273
# val set accuraccy: 85.2 %
# train set accuracy: 58.86875 %
# epoch=62,  avg_loss = 0.9671
# val set accuraccy: 84.19166666666666 %
# train set accuracy: 58.71666666666667 %
# epoch=63,  avg_loss = 0.9862
# val set accuraccy: 84.30833333333334 %
# train set accuracy: 58.73125 %
# epoch=64,  avg_loss = 0.9928
# val set accuraccy: 84.43333333333334 %
# train set accuracy: 58.625 %
# epoch=65,  avg_loss = 0.9612
# val set accuraccy: 83.89166666666667 %
# train set accuracy: 58.53125 %
# epoch=66,  avg_loss = 1.0808
# val set accuraccy: 83.65833333333333 %
# train set accuracy: 58.51875 %
# epoch=67,  avg_loss = 1.0779
# val set accuraccy: 84.19166666666666 %
# train set accuracy: 58.572916666666664 %
# epoch=68,  avg_loss = 1.0180
# val set accuraccy: 83.3 %
# train set accuracy: 58.56666666666667 %
# epoch=69,  avg_loss = 1.0210
# val set accuraccy: 83.74166666666666 %
# train set accuracy: 58.50833333333333 %
# epoch=70,  avg_loss = 1.0478
# val set accuraccy: 83.09166666666667 %
# train set accuracy: 58.50208333333333 %
# epoch=71,  avg_loss = 1.1111
# val set accuraccy: 83.625 %
# train set accuracy: 58.56458333333333 %
# epoch=72,  avg_loss = 1.0628
# val set accuraccy: 83.2 %
# train set accuracy: 58.385416666666664 %
# epoch=73,  avg_loss = 1.0796
# val set accuraccy: 82.95833333333333 %
# train set accuracy: 58.5625 %
# epoch=74,  avg_loss = 1.0663
# val set accuraccy: 84.14166666666667 %
# train set accuracy: 58.666666666666664 %
# epoch=75,  avg_loss = 1.0167
# val set accuraccy: 83.33333333333333 %
# train set accuracy: 58.43125 %
# epoch=76,  avg_loss = 1.0236
# val set accuraccy: 82.66666666666667 %
# train set accuracy: 58.420833333333334 %
# epoch=77,  avg_loss = 1.0431
# val set accuraccy: 82.775 %
# train set accuracy: 58.52291666666667 %
# epoch=78,  avg_loss = 1.0737
# val set accuraccy: 82.60833333333333 %
# train set accuracy: 58.39375 %
# epoch=79,  avg_loss = 1.0919
# val set accuraccy: 83.14166666666667 %
# train set accuracy: 58.4875 %
# epoch=80,  avg_loss = 1.1097
# val set accuraccy: 82.81666666666666 %
# train set accuracy: 58.45625 %
# epoch=81,  avg_loss = 1.1397
# val set accuraccy: 81.54166666666667 %
# train set accuracy: 58.19583333333333 %
# epoch=82,  avg_loss = 1.0628
# val set accuraccy: 82.1 %
# train set accuracy: 58.2625 %
# epoch=83,  avg_loss = 1.0991
# val set accuraccy: 82.48333333333333 %
# train set accuracy: 58.38333333333333 %
# epoch=84,  avg_loss = 1.0067
# val set accuraccy: 82.26666666666667 %
# train set accuracy: 58.45 %
# epoch=85,  avg_loss = 1.1290
# val set accuraccy: 82.2 %
# train set accuracy: 58.291666666666664 %
# epoch=86,  avg_loss = 1.1953
# val set accuraccy: 82.25 %
# train set accuracy: 58.43541666666667 %
# epoch=87,  avg_loss = 1.0802
# val set accuraccy: 81.85 %
# train set accuracy: 58.358333333333334 %
# epoch=88,  avg_loss = 1.0920
# val set accuraccy: 81.14166666666667 %
# train set accuracy: 58.24375 %
# epoch=89,  avg_loss = 1.1788
# val set accuraccy: 80.85833333333333 %
# train set accuracy: 58.047916666666666 %
# epoch=90,  avg_loss = 1.1357
# val set accuraccy: 80.6 %
# train set accuracy: 58.141666666666666 %
# epoch=91,  avg_loss = 1.1440
# val set accuraccy: 80.81666666666666 %
# train set accuracy: 58.08125 %
# epoch=92,  avg_loss = 1.1786
# val set accuraccy: 81.025 %
# train set accuracy: 58.18541666666667 %
# epoch=93,  avg_loss = 1.1665
# val set accuraccy: 81.78333333333333 %
# train set accuracy: 58.30625 %
# epoch=94,  avg_loss = 1.0675
# val set accuraccy: 81.375 %
# train set accuracy: 58.27708333333333 %
# epoch=95,  avg_loss = 1.1944
# train set accuracy: 52.135416666666664 %
# epoch=2,  avg_loss = 0.8773
# val set accuraccy: 85.675 %
# train set accuracy: 52.895833333333336 %
# epoch=3,  avg_loss = 0.7992
# val set accuraccy: 88.41666666666667 %
# train set accuracy: 54.364583333333336 %
# epoch=4,  avg_loss = 0.7358
# val set accuraccy: 88.80833333333334 %
# train set accuracy: 54.7625 %
# epoch=5,  avg_loss = 0.6841
# val set accuraccy: 88.75 %
# train set accuracy: 54.84583333333333 %
# epoch=6,  avg_loss = 0.6817
# val set accuraccy: 88.95833333333333 %
# train set accuracy: 55.360416666666666 %
# epoch=7,  avg_loss = 0.6384
# val set accuraccy: 89.85833333333333 %
# train set accuracy: 55.920833333333334 %
# epoch=8,  avg_loss = 0.5998
# val set accuraccy: 89.95833333333333 %
# train set accuracy: 56.235416666666666 %
# epoch=9,  avg_loss = 0.5780
# val set accuraccy: 89.75 %
# train set accuracy: 56.35 %
# epoch=10,  avg_loss = 0.5637
# val set accuraccy: 90.15833333333333 %
# train set accuracy: 56.50625 %
# epoch=11,  avg_loss = 0.5488
# val set accuraccy: 89.50833333333334 %
# train set accuracy: 56.70625 %
# epoch=12,  avg_loss = 0.5335
# val set accuraccy: 90.10833333333333 %
# train set accuracy: 57.28125 %
# epoch=13,  avg_loss = 0.5375
# val set accuraccy: 90.25833333333334 %
# train set accuracy: 57.05416666666667 %
# epoch=14,  avg_loss = 0.5385
# val set accuraccy: 89.575 %
# train set accuracy: 57.38125 %
# epoch=15,  avg_loss = 0.5224
# val set accuraccy: 90.18333333333334 %
# train set accuracy: 57.77916666666667 %
# epoch=16,  avg_loss = 0.5391
# val set accuraccy: 89.96666666666667 %
# train set accuracy: 57.822916666666664 %
# epoch=17,  avg_loss = 0.5377
# val set accuraccy: 89.83333333333333 %
# train set accuracy: 57.96875 %
# epoch=18,  avg_loss = 0.5317
# val set accuraccy: 90.075 %
# train set accuracy: 58.40416666666667 %
# epoch=19,  avg_loss = 0.5369
# val set accuraccy: 90.26666666666667 %
# train set accuracy: 58.458333333333336 %
# epoch=20,  avg_loss = 0.5572
# val set accuraccy: 89.625 %
# train set accuracy: 58.37083333333333 %
# epoch=21,  avg_loss = 0.5834
# val set accuraccy: 89.75833333333334 %
# train set accuracy: 58.7125 %
# epoch=22,  avg_loss = 0.5921
# val set accuraccy: 89.91666666666667 %
# train set accuracy: 58.64791666666667 %
# epoch=23,  avg_loss = 0.5752
# val set accuraccy: 89.725 %
# train set accuracy: 58.68125 %
# epoch=24,  avg_loss = 0.6041
# val set accuraccy: 89.45 %
# train set accuracy: 58.422916666666666 %
# epoch=25,  avg_loss = 0.5818
# val set accuraccy: 89.24166666666666 %
# train set accuracy: 58.825 %
# epoch=26,  avg_loss = 0.5825
# val set accuraccy: 89.05833333333334 %
# train set accuracy: 58.78958333333333 %
# epoch=27,  avg_loss = 0.5938
# val set accuraccy: 89.06666666666666 %
# train set accuracy: 58.80416666666667 %
# epoch=28,  avg_loss = 0.6428
# val set accuraccy: 89.25833333333334 %
# train set accuracy: 59.014583333333334 %
# epoch=29,  avg_loss = 0.6370
# val set accuraccy: 88.09166666666667 %
# train set accuracy: 58.55833333333333 %
# epoch=30,  avg_loss = 0.5956
# val set accuraccy: 88.69166666666666 %
# train set accuracy: 58.975 %
# epoch=31,  avg_loss = 0.6236
# val set accuraccy: 89.075 %
# train set accuracy: 59.083333333333336 %
# epoch=32,  avg_loss = 0.6262
# val set accuraccy: 88.95833333333333 %
# train set accuracy: 59.19375 %
# epoch=33,  avg_loss = 0.6602
# val set accuraccy: 88.35833333333333 %
# train set accuracy: 59.15833333333333 %
# epoch=34,  avg_loss = 0.6317
# val set accuraccy: 88.31666666666666 %
# train set accuracy: 59.16041666666667 %
# epoch=35,  avg_loss = 0.6374
# val set accuraccy: 87.79166666666667 %
# train set accuracy: 59.12083333333333 %
# epoch=36,  avg_loss = 0.6333
# val set accuraccy: 88.31666666666666 %
# train set accuracy: 59.1875 %
# epoch=37,  avg_loss = 0.7077
# val set accuraccy: 88.2 %
# train set accuracy: 59.16458333333333 %
# epoch=38,  avg_loss = 0.8400
# val set accuraccy: 87.75833333333334 %
# train set accuracy: 59.1875 %
# epoch=39,  avg_loss = 0.8288
# val set accuraccy: 87.7 %
# train set accuracy: 59.1 %
# epoch=40,  avg_loss = 0.8325
# val set accuraccy: 87.0 %
# train set accuracy: 58.99583333333333 %
# epoch=41,  avg_loss = 0.8842
# val set accuraccy: 87.275 %
# train set accuracy: 59.0625 %
# epoch=42,  avg_loss = 0.9281
# val set accuraccy: 87.05 %
# train set accuracy: 59.114583333333336 %
# epoch=43,  avg_loss = 0.9076
# val set accuraccy: 86.50833333333334 %
# train set accuracy: 58.99791666666667 %
# epoch=44,  avg_loss = 0.9766
# val set accuraccy: 86.34166666666667 %
# train set accuracy: 58.84583333333333 %
# epoch=45,  avg_loss = 0.9608
# val set accuraccy: 86.35 %
# train set accuracy: 59.041666666666664 %
# epoch=46,  avg_loss = 0.9766
# val set accuraccy: 86.45833333333333 %
# train set accuracy: 58.9875 %
# epoch=47,  avg_loss = 0.9553
# val set accuraccy: 86.48333333333333 %
# train set accuracy: 59.03541666666667 %
# epoch=48,  avg_loss = 0.9696
# val set accuraccy: 86.10833333333333 %
# train set accuracy: 58.98125 %
# epoch=49,  avg_loss = 0.9902
# val set accuraccy: 85.50833333333334 %
# train set accuracy: 58.90416666666667 %
# epoch=50,  avg_loss = 0.9789
# val set accuraccy: 85.9 %
# train set accuracy: 58.89791666666667 %
# epoch=51,  avg_loss = 0.9552
# val set accuraccy: 85.76666666666667 %
# train set accuracy: 58.92916666666667 %
# epoch=52,  avg_loss = 0.9641
# val set accuraccy: 85.53333333333333 %
# train set accuracy: 58.84375 %
# epoch=53,  avg_loss = 0.9955
# val set accuraccy: 85.29166666666667 %
# train set accuracy: 58.94166666666667 %
# epoch=54,  avg_loss = 1.0170
# val set accuraccy: 84.19166666666666 %
# train set accuracy: 58.69166666666667 %
# epoch=55,  avg_loss = 1.0010
# val set accuraccy: 84.825 %
# train set accuracy: 58.77708333333333 %
# epoch=56,  avg_loss = 1.0467
# val set accuraccy: 84.63333333333334 %
# train set accuracy: 58.75 %
# ...
# val set accuraccy: 87.58333333333333 %
# train set accuracy: 59.1375 %
# epoch=42,  avg_loss = 0.8891
# val set accuraccy: 86.49166666666666 %
# train set accuracy: 59.05 %
# epoch=43,  avg_loss = 0.9111
# val set accuraccy: 86.49166666666666 %
# train set accuracy: 59.016666666666666 %
# epoch=44,  avg_loss = 0.9366
# val set accuraccy: 86.06666666666666 %
# train set accuracy: 58.94166666666667 %
# epoch=45,  avg_loss = 0.9450
# val set accuraccy: 86.64166666666667 %
# train set accuracy: 59.052083333333336 %
# epoch=46,  avg_loss = 0.9680
# val set accuraccy: 86.14166666666667 %
# train set accuracy: 58.94166666666667 %
# epoch=47,  avg_loss = 0.9609
# val set accuraccy: 86.40833333333333 %
# train set accuracy: 58.99375 %
# epoch=48,  avg_loss = 0.9958
# val set accuraccy: 85.44166666666666 %
# train set accuracy: 58.86666666666667 %
# epoch=49,  avg_loss = 1.0005
# val set accuraccy: 85.01666666666667 %
# train set accuracy: 58.860416666666666 %
# epoch=50,  avg_loss = 0.9900
# val set accuraccy: 85.70833333333333 %
# train set accuracy: 58.9625 %
# epoch=51,  avg_loss = 0.9928
# val set accuraccy: 85.55 %
# train set accuracy: 58.91875 %
# epoch=52,  avg_loss = 1.0080
# val set accuraccy: 85.19166666666666 %
# train set accuracy: 58.825 %
# epoch=53,  avg_loss = 1.0226
# val set accuraccy: 85.48333333333333 %
# train set accuracy: 58.91041666666667 %
# epoch=54,  avg_loss = 1.0149
# val set accuraccy: 85.225 %
# train set accuracy: 58.739583333333336 %
# epoch=55,  avg_loss = 1.0471
# val set accuraccy: 84.75 %
# train set accuracy: 58.764583333333334 %
# epoch=56,  avg_loss = 1.0572
# val set accuraccy: 85.13333333333334 %
# train set accuracy: 58.827083333333334 %
# epoch=57,  avg_loss = 1.0108
# val set accuraccy: 84.90833333333333 %
# train set accuracy: 58.8 %
# epoch=58,  avg_loss = 1.0755
# val set accuraccy: 83.625 %
# train set accuracy: 58.572916666666664 %
# epoch=59,  avg_loss = 1.1206
# val set accuraccy: 83.85 %
# train set accuracy: 58.55833333333333 %
# epoch=60,  avg_loss = 1.1352
# val set accuraccy: 84.3 %
# train set accuracy: 58.80416666666667 %
# epoch=61,  avg_loss = 1.1335
# val set accuraccy: 83.175 %
# train set accuracy: 58.47708333333333 %
# epoch=62,  avg_loss = 1.1547
# val set accuraccy: 83.375 %
# train set accuracy: 58.666666666666664 %
# epoch=63,  avg_loss = 1.1027
# val set accuraccy: 83.18333333333334 %
# train set accuracy: 58.577083333333334 %
# epoch=64,  avg_loss = 1.1980
# val set accuraccy: 83.03333333333333 %
# train set accuracy: 58.45 %
# epoch=65,  avg_loss = 1.2308
# val set accuraccy: 82.53333333333333 %
# train set accuracy: 58.454166666666666 %
# epoch=66,  avg_loss = 1.1684
# val set accuraccy: 82.05 %
# train set accuracy: 58.33541666666667 %
# epoch=67,  avg_loss = 1.2583
# val set accuraccy: 83.125 %
# train set accuracy: 58.5625 %
# epoch=68,  avg_loss = 1.2339
# val set accuraccy: 81.30833333333334 %
# train set accuracy: 58.15208333333333 %
# epoch=69,  avg_loss = 1.2199
# val set accuraccy: 81.225 %
# train set accuracy: 58.083333333333336 %
# epoch=70,  avg_loss = 1.2252
# val set accuraccy: 81.3 %
# train set accuracy: 58.295833333333334 %
# epoch=71,  avg_loss = 1.2573
# val set accuraccy: 82.15833333333333 %
# train set accuracy: 58.452083333333334 %
# epoch=72,  avg_loss = 1.2426
# val set accuraccy: 80.95 %
# train set accuracy: 58.045833333333334 %
# epoch=73,  avg_loss = 1.2504
# val set accuraccy: 80.70833333333333 %
# train set accuracy: 58.16875 %
# epoch=74,  avg_loss = 1.2932
# val set accuraccy: 82.1 %
# train set accuracy: 58.297916666666666 %
# epoch=75,  avg_loss = 1.2925
# val set accuraccy: 81.25 %
# train set accuracy: 58.19375 %
# epoch=76,  avg_loss = 1.2608
# val set accuraccy: 80.30833333333334 %
# train set accuracy: 57.891666666666666 %
# epoch=77,  avg_loss = 1.2971
# val set accuraccy: 81.44166666666666 %
# train set accuracy: 58.23125 %
# epoch=78,  avg_loss = 1.3286
# val set accuraccy: 79.30833333333334 %
# train set accuracy: 57.80833333333333 %
# epoch=79,  avg_loss = 1.3082
# val set accuraccy: 81.08333333333333 %
# train set accuracy: 58.0625 %
# epoch=80,  avg_loss = 1.3285
# val set accuraccy: 80.5 %
# train set accuracy: 57.922916666666666 %
# epoch=81,  avg_loss = 1.3621
# val set accuraccy: 80.26666666666667 %
# train set accuracy: 58.03541666666667 %
# epoch=82,  avg_loss = 1.3538
# val set accuraccy: 78.8 %
# train set accuracy: 57.95 %
# epoch=83,  avg_loss = 1.4119
# val set accuraccy: 79.49166666666666 %
# train set accuracy: 57.81458333333333 %
# epoch=84,  avg_loss = 1.4284
# val set accuraccy: 78.9 %
# train set accuracy: 58.02916666666667 %
# epoch=85,  avg_loss = 1.4689
# val set accuraccy: 78.80833333333334 %
# train set accuracy: 57.91041666666667 %
# epoch=86,  avg_loss = 1.5113
# val set accuraccy: 79.21666666666667 %
# train set accuracy: 57.954166666666666 %
# epoch=87,  avg_loss = 1.5177
# val set accuraccy: 80.61666666666666 %
# train set accuracy: 58.297916666666666 %
# epoch=88,  avg_loss = 1.5020
# val set accuraccy: 78.70833333333333 %
# train set accuracy: 58.079166666666666 %
# epoch=89,  avg_loss = 1.4626
# val set accuraccy: 79.50833333333334 %
# train set accuracy: 57.9125 %
# epoch=90,  avg_loss = 1.4126
# val set accuraccy: 79.15833333333333 %
# train set accuracy: 57.88333333333333 %
# epoch=91,  avg_loss = 1.4829
# val set accuraccy: 77.59166666666667 %
# train set accuracy: 57.825 %
# epoch=92,  avg_loss = 1.4852
# val set accuraccy: 76.725 %
# train set accuracy: 57.59791666666667 %
# epoch=93,  avg_loss = 1.5472
# val set accuraccy: 77.175 %
# train set accuracy: 57.7125 %
# epoch=94,  avg_loss = 1.5011
# val set accuraccy: 76.95 %
# train set accuracy: 57.65416666666667 %
# epoch=95,  avg_loss = 1.5650
# val set accuraccy: 77.41666666666667 %
# train set accuracy: 57.53541666666667 %
# epoch=96,  avg_loss = 1.5487
# val set accuraccy: 76.0 %
# train set accuracy: 57.22083333333333 %
# epoch=97,  avg_loss = 1.6006
# val set accuraccy: 78.05833333333334 %
# train set accuracy: 57.770833333333336 %
# epoch=98,  avg_loss = 1.5551
# val set accuraccy: 78.23333333333333 %
# train set accuracy: 57.729166666666664 %
# epoch=99,  avg_loss = 1.5151
# val set accuraccy: 76.59166666666667 %
# train set accuracy: 57.40625 %
# epoch=100,  avg_loss = 1.5618
# val set accuraccy: 77.575 %
# train set accuracy: 57.610416666666666 %
# epoch=101,  avg_loss = 1.5931
# val set accuraccy: 76.9 %
# train set accuracy: 57.525 %
# epoch=102,  avg_loss = 1.6044
# val set accuraccy: 77.16666666666667 %
# train set accuracy: 57.672916666666666 %
# epoch=103,  avg_loss = 1.6193
# val set accuraccy: 74.91666666666667 %
# train set accuracy: 57.204166666666666 %
# epoch=104,  avg_loss = 1.5846
# val set accuraccy: 76.33333333333333 %
# train set accuracy: 57.485416666666666 %
# epoch=105,  avg_loss = 1.6088
# val set accuraccy: 74.75833333333334 %
# train set accuracy: 57.125 %
# epoch=106,  avg_loss = 1.6346
# val set accuraccy: 74.98333333333333 %
# train set accuracy: 57.30416666666667 %
# epoch=107,  avg_loss = 1.6549
# val set accuraccy: 76.05833333333334 %
# train set accuracy: 57.38125 %
# epoch=108,  avg_loss = 1.6451
# val set accuraccy: 75.24166666666666 %
# train set accuracy: 57.2375 %
# epoch=109,  avg_loss = 1.6683
# val set accuraccy: 75.8 %
# train set accuracy: 57.2875 %
# epoch=110,  avg_loss = 1.6588
# val set accuraccy: 73.0 %
# train set accuracy: 57.03125 %
# epoch=111,  avg_loss = 1.7103
# val set accuraccy: 75.53333333333333 %
# train set accuracy: 57.266666666666666 %
# epoch=112,  avg_loss = 1.6971
# val set accuraccy: 76.18333333333334 %
# train set accuracy: 57.666666666666664 %
# epoch=113,  avg_loss = 1.6964
# val set accuraccy: 74.38333333333334 %
# train set accuracy: 57.18958333333333 %
# epoch=114,  avg_loss = 1.6741
# val set accuraccy: 73.88333333333334 %
# train set accuracy: 57.05416666666667 %
# epoch=115,  avg_loss = 1.7330
# val set accuraccy: 73.24166666666666 %
# train set accuracy: 57.02916666666667 %
# epoch=116,  avg_loss = 1.7335
# val set accuraccy: 71.84166666666667 %
# train set accuracy: 56.9625 %
# epoch=117,  avg_loss = 1.7268
# val set accuraccy: 71.58333333333333 %
# train set accuracy: 56.88125 %
# epoch=118,  avg_loss = 1.7617
# val set accuraccy: 74.15 %
# train set accuracy: 57.27291666666667 %
# epoch=119,  avg_loss = 1.7593
# epoch=146,  avg_loss = 1.8023
# val set accuraccy: 67.4 %
# train set accuracy: 56.239583333333336 %
# epoch=147,  avg_loss = 1.7969
# val set accuraccy: 67.98333333333333 %
# train set accuracy: 56.3125 %
# epoch=148,  avg_loss = 1.7914
# val set accuraccy: 67.71666666666667 %
# train set accuracy: 56.325 %
# epoch=149,  avg_loss = 1.8183
# val set accuraccy: 69.475 %
# train set accuracy: 56.53333333333333 %
# epoch=150,  avg_loss = 1.8117
# val set accuraccy: 68.725 %
# train set accuracy: 56.47708333333333 %
# epoch=151,  avg_loss = 1.7964
# val set accuraccy: 68.25 %
# train set accuracy: 56.422916666666666 %
# epoch=152,  avg_loss = 1.8124
# val set accuraccy: 70.96666666666667 %
# train set accuracy: 56.766666666666666 %
# epoch=153,  avg_loss = 1.7966
# val set accuraccy: 65.85 %
# train set accuracy: 56.24166666666667 %
# epoch=154,  avg_loss = 1.7997
# val set accuraccy: 67.6 %
# train set accuracy: 56.26875 %
# epoch=155,  avg_loss = 1.7911
# val set accuraccy: 68.11666666666666 %
# train set accuracy: 56.25 %
# epoch=156,  avg_loss = 1.8093
# val set accuraccy: 67.78333333333333 %
# train set accuracy: 56.46875 %
# epoch=157,  avg_loss = 1.8193
# val set accuraccy: 67.975 %
# train set accuracy: 56.2875 %
# epoch=158,  avg_loss = 1.8244
# val set accuraccy: 67.29166666666667 %
# train set accuracy: 56.177083333333336 %
# epoch=159,  avg_loss = 1.8111
# val set accuraccy: 67.35833333333333 %
# train set accuracy: 56.19375 %
# epoch=160,  avg_loss = 1.8099
# val set accuraccy: 64.79166666666667 %
# train set accuracy: 55.94166666666667 %
# epoch=161,  avg_loss = 1.8280
# val set accuraccy: 70.0 %
# train set accuracy: 56.60208333333333 %
# epoch=162,  avg_loss = 1.8058
# val set accuraccy: 65.76666666666667 %
# train set accuracy: 56.083333333333336 %
# epoch=163,  avg_loss = 1.8206
# val set accuraccy: 66.01666666666667 %
# train set accuracy: 56.235416666666666 %
# epoch=164,  avg_loss = 1.8420
# val set accuraccy: 67.45833333333333 %
# train set accuracy: 56.4 %
# epoch=165,  avg_loss = 1.8364
# val set accuraccy: 67.69166666666666 %
# train set accuracy: 56.49375 %
# epoch=166,  avg_loss = 1.8312
# val set accuraccy: 67.23333333333333 %
# train set accuracy: 56.38125 %
# epoch=167,  avg_loss = 1.8301
# val set accuraccy: 68.96666666666667 %
# train set accuracy: 56.48125 %
# epoch=168,  avg_loss = 1.8289
# val set accuraccy: 67.975 %
# train set accuracy: 56.38125 %
# epoch=169,  avg_loss = 1.8099
# val set accuraccy: 65.29166666666667 %
# train set accuracy: 56.03958333333333 %
# epoch=170,  avg_loss = 1.7983
# val set accuraccy: 68.525 %
# train set accuracy: 56.208333333333336 %
# epoch=171,  avg_loss = 1.7970
# val set accuraccy: 66.55833333333334 %
# train set accuracy: 56.21875 %
# epoch=172,  avg_loss = 1.7975
# val set accuraccy: 67.04166666666667 %
# train set accuracy: 56.2125 %
# epoch=173,  avg_loss = 1.8003
# val set accuraccy: 66.30833333333334 %
# train set accuracy: 56.24583333333333 %
# epoch=174,  avg_loss = 1.7927
# val set accuraccy: 68.49166666666666 %
# train set accuracy: 56.44166666666667 %
# epoch=175,  avg_loss = 1.8082
# val set accuraccy: 66.53333333333333 %
# train set accuracy: 56.24375 %
# epoch=176,  avg_loss = 1.7696
# val set accuraccy: 70.275 %
# train set accuracy: 56.72083333333333 %
# epoch=177,  avg_loss = 1.7936
# val set accuraccy: 67.86666666666666 %
# train set accuracy: 56.291666666666664 %
# epoch=178,  avg_loss = 1.8000
# val set accuraccy: 68.275 %
# train set accuracy: 56.3375 %
# epoch=179,  avg_loss = 1.7995
# val set accuraccy: 65.5 %
# train set accuracy: 55.94583333333333 %
# epoch=180,  avg_loss = 1.7921
# val set accuraccy: 68.30833333333334 %
# train set accuracy: 56.39791666666667 %
# epoch=181,  avg_loss = 1.7748
# val set accuraccy: 66.93333333333334 %
# train set accuracy: 56.1375 %
# epoch=182,  avg_loss = 1.8065
# val set accuraccy: 65.68333333333334 %
# train set accuracy: 56.03541666666667 %
# epoch=183,  avg_loss = 1.7928
# val set accuraccy: 66.29166666666667 %
# train set accuracy: 56.110416666666666 %
# epoch=184,  avg_loss = 1.7776
# val set accuraccy: 65.925 %
# train set accuracy: 56.09375 %
# epoch=185,  avg_loss = 1.7851
# val set accuraccy: 64.90833333333333 %
# train set accuracy: 56.0125 %
# epoch=186,  avg_loss = 1.7795
# val set accuraccy: 65.525 %
# train set accuracy: 56.125 %
# epoch=187,  avg_loss = 1.7873
# val set accuraccy: 65.5 %
# train set accuracy: 56.08541666666667 %
# epoch=188,  avg_loss = 1.7922
# val set accuraccy: 66.31666666666666 %
# train set accuracy: 56.29375 %
# epoch=189,  avg_loss = 1.8017
# val set accuraccy: 64.3 %
# train set accuracy: 55.99375 %
# epoch=190,  avg_loss = 1.8002
# val set accuraccy: 68.59166666666667 %
# train set accuracy: 56.55416666666667 %
# epoch=191,  avg_loss = 1.7887
# val set accuraccy: 64.39166666666667 %
# train set accuracy: 55.99375 %
# epoch=192,  avg_loss = 1.8037
# val set accuraccy: 65.15 %
# train set accuracy: 55.99583333333333 %
# epoch=193,  avg_loss = 1.7949
# val set accuraccy: 65.36666666666666 %
# train set accuracy: 55.99375 %
# epoch=194,  avg_loss = 1.7773
# val set accuraccy: 65.8 %
# train set accuracy: 56.045833333333334 %
# epoch=195,  avg_loss = 1.7913
# val set accuraccy: 67.6 %
# train set accuracy: 56.20625 %
# epoch=196,  avg_loss = 1.7800
# val set accuraccy: 66.64166666666667 %
# train set accuracy: 56.21041666666667 %
# epoch=197,  avg_loss = 1.8004
# val set accuraccy: 67.75833333333334 %
# train set accuracy: 56.34375 %
# epoch=198,  avg_loss = 1.7998
# val set accuraccy: 64.15 %
# train set accuracy: 55.8875 %
# epoch=199,  avg_loss = 1.8442
# val set accuraccy: 66.00833333333334 %
# train set accuracy: 56.045833333333334 %
# Finished Training
